# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv('iris.csv')
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# ### Correlation

# %%
# Selecting only numerical columns
numerical_df = df.select_dtypes(include=['float64', 'int64'])

# correlation matrix
correlation_matrix = numerical_df.corr()

print(correlation_matrix)
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000

# %% [markdown]
# ### Correlation matrix with the help of formula

# %%
import numpy as np
import pandas as pd

def compute_correlation_matrix(df):
   
    numerical_df = df.select_dtypes(include=['float64', 'int64'])
    data = numerical_df.to_numpy()
    means = np.mean(data, axis=0)
    centered_data = data - means 
    cov_matrix = np.cov(centered_data, rowvar=False, bias=False)
    std_devs = np.sqrt(np.diag(cov_matrix))
    corr_matrix = cov_matrix / np.outer(std_devs, std_devs)
    corr_df = pd.DataFrame(corr_matrix, index=numerical_df.columns, columns=numerical_df.columns)
    return corr_df
correlation_matrix = compute_correlation_matrix(df)
print(correlation_matrix)
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000

# %% [markdown]
# ### Plotting correlation matrix

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', square=True, cbar_kws={"shrink": .8})
plt.title('Correlation Matrix of Iris Dataset')
plt.show()

# %%
sns.pairplot(df)
plt.suptitle('Pair plot of Iris Df',y=1.02)
plt.show()

# %% [markdown]
# Here we can see and observe the correlation bewteen different features

# %% [markdown]
# ### Covariance Matrix

# %%
cov_mat= df[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']].cov()

# %%
print(cov_mat)
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       0.685694     -0.039268       1.273682      0.516904
# SepalWidthCm       -0.039268      0.188004      -0.321713     -0.117981
# PetalLengthCm       1.273682     -0.321713       3.113179      1.296387
# PetalWidthCm        0.516904     -0.117981       1.296387      0.582414
